# %% [markdown]
# ### FINDING UNIQUE DATA IN COLUMNS

# %%
import pandas as pd

# import csv in dataframe
df = pd.read_csv('../data/raw/wonka_choc_factory.csv')
print("Shape : ", df.shape)
df.head()
# Out:
# Shape :  (10194, 19)
#    Unnamed: 0  Order Date   Ship Date       Ship Mode  Customer ID  \
# 0           0  2021-03-31  2026-09-26  Standard Class       128055
# 1           1  2021-03-31  2026-09-26  Standard Class       128055
# 2           2  2021-09-15  2027-03-13  Standard Class       138100
# 3           3  2021-09-15  2027-03-13  Standard Class       138100
# 4           4  2022-10-04  2028-03-29     First Class       121391
#
#   Country/Region           City State/Province Postal Code   Division  \
# 0  United States  San Francisco     California       94122  Chocolate
# 1  United States  San Francisco     California       94122  Chocolate
# 2  United States  New York City       New York       10011  Chocolate
# 3  United States  New York City       New York       10011  Chocolate
# 4  United States  San Francisco     California       94109  Chocolate
#
#      Region                       Product Name  Sales  Units  Gross Profit  \
# 0   Pacific  Wonka Bar - Triple Dazzle Caramel   7.50      2          4.90
# 1   Pacific     Wonka Bar -Scrumdiddlyumptious   7.20      2          5.00
# 2  Atlantic          Wonka Bar - Fudge Mallows   7.20      2          4.80
# 3  Atlantic         Wonka Bar - Milk Chocolate   9.75      3          6.33
# 4   Pacific         Wonka Bar - Milk Chocolate   6.50      2          4.22
#
#    Cost          Factory   Latitude   Longitude
# 0  2.60  Wicked Choccy's  32.076176  -81.088371
# 1  2.20    Lot's O' Nuts  32.881893 -111.768036
# 2  2.40    Lot's O' Nuts  32.881893 -111.768036
# 3  3.42  Wicked Choccy's  32.076176  -81.088371
# 4  2.28  Wicked Choccy's  32.076176  -81.088371

# %% [markdown]
# =============================================================================================
# ##  BUSINESS DEFINITION & CASE
# =============================================================================================
# - product profitability to invest in more and redefine selling price for low profitability products
# - factory performance to expend it for quantity of the best performing products
# - strategies to improve profitability and create marketing compaigns to present the product line
#
# - fidelity strategy : figure out the top customers and give them a discount for a higher amounts of sales
#
# - Three Slides :
#
# --- (6 Best / Worst Products)
#
# --- (USA vs Canada Country  - 5 State/Region of best country)
#
# --- (10 City of best region)
#
#
# ERD (Entity Relational Diagram / Schema)
# Entities:
#
# - Factory Info
# + Factory
# + Latitude
# + Longitude
#
# - Factory Address
# * Latitude (foreign key)
# * Longitude (foreign key)
# + calculate address using API (later We could split it into Country, Region, City, Postal Code)
#
# - Product
# + Product Name
# * Division (primary key)
#
# - Order (has one address and has one customer)
# + Order Date
# + Sales	Units
# + Gross Profit
# + Cost
# * Division (foreign key)
#
# - Shipping (an order has one shipping date and mode)
# + Ship Date
# + Ship Mode
#
# - Delivery Address (has one order)
# + Country/Region
# + City
# + State/Province
# + Postal Code
# + Region
#
# - Customer (has multiple orders)
# * Customer ID (primary key)
# + Orders Number

# %%
df["Product Name"].unique()
# Out:
# array(['Wonka Bar - Triple Dazzle Caramel',
#        'Wonka Bar -Scrumdiddlyumptious', 'Wonka Bar - Fudge Mallows',
#        'Wonka Bar - Milk Chocolate', 'Wonka Bar - Nutty Crunch Surprise',
#        'Wonka Gum', 'SweeTARTS', 'Lickable Wallpaper', 'Kazookles',
#        'Everlasting Gobstopper', 'Fizzy Lifting Drinks', 'Nerds',
#        'Fun Dip', 'Laffy Taffy', 'Hair Toffee'], dtype=object)

# %% [markdown]
# # CREATING A PRODUCT ID :
# | Product Name | Product ID |
# |-----|-----|
# | Wonka Bar | ```WB``` |
# | Wonka Bar - Triple Dazzle Caramel | ```WBTC``` |
# | Wonka Bar -Scrumdiddlyumptious | ```WBSL``` |
# | Wonka Bar - Fudge Mallows | ```WBFM``` |
# | Wonka Bar - Milk Chocolate | ```WBMC``` |
# | Wonka Bar - Nutty Crunch Surprise |```WBNS```|
# | Wonka Gum | ```WG``` |
# | SweeTARTS | ```ST``` |
# | Lickable Wallpaper | ```LW``` |
# | Kazookles | ```KK``` |
# | Everlasting Gobstopper | ```EG```|
# | Fizzy Lifting Drinks | ```FL``` |
# | Nerds | ```ND```|
# | Fun Dip | ```FD```|
# | Laffy Taffy | ```LT```|
# | Hair Toffee | ```HT```|

# %%
df["State/Province"].unique()
# Out:
# array(['California', 'New York', 'Texas', 'Minnesota', 'Nebraska',
#        'Oregon', 'Tennessee', 'Arizona', 'Georgia', 'Rhode Island',
#        'Connecticut', 'Missouri', 'Michigan', 'North Carolina',
#        'Pennsylvania', 'Massachusetts', 'Oklahoma', 'Kentucky',
#        'Washington', 'Virginia', 'New Hampshire', 'Indiana', 'Illinois',
#        'British Columbia', 'Colorado', 'Ohio', 'Mississippi',
#        'New Mexico', 'Florida', 'Louisiana', 'Montana', 'New Jersey',
#        'Utah', 'Ontario', 'Nevada', 'Wisconsin', 'Alabama', 'Maryland',
#        'South Carolina', 'Quebec', 'Iowa', 'Kansas', 'Delaware',
#        'South Dakota', 'Vermont', 'Arkansas', 'North Dakota',
#        'District of Columbia', 'Idaho', 'West Virginia', 'Alberta',
#        'Prince Edward Island', 'Manitoba', 'Newfoundland and Labrador',
#        'Maine', 'Wyoming', 'New Brunswick', 'Nova Scotia', 'Saskatchewan'],
#       dtype=object)

# %% [markdown]
# =============================================================================================
# ## QUESTIONS
# =============================================================================================
# - General profit vs loss by
# - Business idea / decision?
# - What's the problem of our business based on what we have as data?
# - B2B supplying chocolate, sugar and other

# %%
df["City"].unique()
# Out:
# array(['San Francisco', 'New York City', 'Round Rock', 'Minneapolis',
#        'Los Angeles', 'Rancho Cucamonga', 'Omaha', 'Salem', 'Lebanon',
#        'Mesa', 'Atlanta', 'Providence', 'Middletown', 'Springfield',
#        'Detroit', 'Concord', 'Chester', 'Lowell', 'Oklahoma City',
#        'Georgetown', 'San Diego', 'Arlington', 'Seattle', 'Des Moines',
#        'Waynesboro', 'Philadelphia', 'Greenwood', 'Indianapolis',
#        'Houston', 'Phoenix', 'Portland', 'Pearland', 'Bloomington',
#        'Henderson', 'Yonkers', 'Tulsa', 'Dallas', 'Long Beach',
#        'Carrollton', 'Decatur', 'Vancouver', 'Louisville', 'Lakewood',
#        'Toledo', 'Bellevue', 'Plano', 'Jackson', 'Lorain', 'Carlsbad',
#        'Chicago', 'Jacksonville', 'Tucson', 'Avondale', 'Tampa',
#        'Pembroke Pines', 'Lafayette', 'Beaumont', 'Rochester', 'Parma',
#        'Lawrence', 'Huntsville', 'Great Falls', 'Fairfield',
#        'San Clemente', 'Passaic', 'Homestead', 'College Station',
#        'West Jordan', 'Toronto', 'Las Vegas', 'Franklin', 'Stockton',
#        'Charlotte', 'Cincinnati', 'Knoxville', 'Alexandria',
#        'Saint Petersburg', 'Peoria', 'Richmond', 'Allen', 'Milwaukee',
#        'Columbus', 'Hampton', 'Waterbury', 'Eau Claire', 'Coral Springs',
#        'Troy', 'Gulfport', 'Huntington Beach', 'Cranston', 'Aurora',
#        'Bethlehem', 'Tamarac', 'Brentwood', 'Nashville', 'Anaheim',
#        'Bartlett', 'Miami', 'Virginia Beach', 'Roswell', 'Plantation',
#        'Coral Gables', 'Kent', 'Roseville', 'Glendale', 'Chesapeake',
#        'Beverly', 'Palm Coast', 'Baltimore', 'Scottsdale', 'Apple Valley',
#        'Wilmington', 'Taylor', 'Chandler', 'Grand Prairie', 'Cleveland',
#        'Auburn', 'Des Plaines', 'Frisco', 'Florence', 'Malden',
#        'Fort Lauderdale', 'Denver', 'Rock Hill', 'Fort Collins',
#        'Montreal', 'Austin', 'Hattiesburg', 'Trenton', 'Woonsocket',
#        'Quincy', 'Redmond', 'Pasadena', 'Irving', 'Charlottesville',
#        'Montgomery', 'Longmont', 'Provo', 'Redondo Beach', 'Noblesville',
#        'Palatine', 'Boynton Beach', 'Akron', 'Meriden', 'Bristol',
#        'Morristown', 'Farmington', 'Bakersfield', 'Helena', 'Oceanside',
#        'Wheeling', 'San Antonio', 'Sierra Vista', 'Inglewood',
#        'Saint Charles', 'Fort Worth', 'Vineland', 'Columbia', 'Oakland',
#        'El Cajon', 'Odessa', 'Laguna Niguel', 'Woodland', 'Green Bay',
#        'Newport News', 'Fresno', 'Monroe', 'Lancaster', 'Lawton',
#        'Bowling Green', 'Newark', 'Edmonds', 'Rome', 'Appleton', 'Olathe',
#        'Fayetteville', 'Modesto', 'Raleigh', 'Sacramento', 'Albuquerque',
#        'Memphis', 'The Colony', 'Greensboro', 'Watertown', 'Woodstock',
#        'Garden City', 'Delray Beach', 'Quebec City', 'Hialeah',
#        'Johnson City', 'San Bernardino', 'Santa Ana', 'Santa Barbara',
#        'Gaithersburg', 'Montebello', 'Ann Arbor', 'Elyria',
#        'Buffalo Grove', 'Deltona', 'Harrisonburg', 'Cary', 'Lakeville',
#        'Broken Arrow', 'Plainfield', 'Oxnard', 'El Paso', 'Paterson',
#        'Arvada', 'Spokane', 'Evanston', 'Skokie', 'Gilbert',
#        'San Gabriel', 'Superior', 'Costa Mesa', 'Altoona', 'Littleton',
#        'Frankfort', 'Clinton', 'Milford', 'Smyrna', 'Rapid City',
#        'Port Arthur', 'Warwick', 'Hoover', 'Waco', 'Chattanooga',
#        'Hamilton', 'Cedar Hill', 'East Orange', 'Cuyahoga Falls',
#        'Camarillo', 'Burlington', 'Southaven', 'Chapel Hill', 'Owensboro',
#        'La Porte', 'Westminster', 'Moorhead', 'Durham', 'Lubbock',
#        'Lake Elsinore', 'Wichita', 'Medford', 'Tyler', 'Moreno Valley',
#        'Shelton', 'Allentown', 'Hempstead', 'Apopka', 'Hillsboro',
#        'Santa Clara', 'Mcallen', 'Everett', 'Renton', 'Orem',
#        'Hot Springs', 'Marietta', 'Little Rock', 'Grove City', 'Linden',
#        'Gresham', 'Urbandale', 'Reading', 'Colorado Springs',
#        'New Bedford', 'Brownsville', 'Utica', 'North Charleston',
#        'Redlands', 'Covington', 'Norwich', 'Elmhurst', 'Grand Rapids',
#        'West Palm Beach', 'Lakeland', 'Freeport', 'Englewood',
#        'Iowa City', 'Bossier City', 'Woodbury', 'Haltom City',
#        'Hollywood', 'Dublin', 'San Jose', 'Fargo', 'Conroe', 'Pomona',
#        'Thomasville', 'Fremont', 'Bozeman', 'Washington', 'Lake Forest',
#        'Salinas', 'Marion', 'Port Saint Lucie', 'Hickory',
#        'Salt Lake City', 'Riverside', 'Orlando', 'Asheville',
#        'North Miami', 'Cottage Grove', 'Warner Robins', 'Dubuque',
#        'Vallejo', 'Rockford', 'Orange', 'Murfreesboro', 'Tempe',
#        'Kenosha', 'Miramar', 'Hendersonville', 'Westland', 'Abilene',
#        'Keller', 'Greenville', 'Eagan', 'Romeoville', 'Las Cruces',
#        'Thousand Oaks', 'Lincoln Park', 'Yuma', 'Encinitas', 'Pine Bluff',
#        'New Albany', 'Meridian', 'Murray', 'Revere', 'Westfield',
#        'Maple Grove', 'North Las Vegas', 'Tuscaloosa', 'Normal',
#        'Lake Charles', 'Jamestown', 'Amarillo', 'Mason', 'Mansfield',
#        'Buffalo', 'Redding', 'La Crosse', 'Laredo', 'Naperville', 'Lodi',
#        'Jonesboro', 'Lansing', 'Escondido', 'Jefferson City', 'Dover',
#        'Sandy Springs', 'Sioux Falls', 'Lehi', 'Dearborn Heights',
#        'Saint Paul', 'Melbourne', 'Pueblo', 'Torrance', 'Mesquite',
#        'Bryan', 'Bolingbrook', 'Mount Pleasant', 'Rogers', 'Bellingham',
#        'Calgary', 'Edmonton', 'Antioch', 'Chico', 'Perth Amboy',
#        'Richardson', 'Hesperia', 'Pharr', 'Leominster', 'Harlingen',
#        'Texas City', 'Rio Rancho', 'Bullhead City', 'Cambridge', 'Kenner',
#        'Boise', 'Loveland', 'Charlottetown', 'Mount Vernon', 'Sunnyvale',
#        'Longview', 'Chula Vista', 'Danbury', 'Macon', 'Tallahassee',
#        'Belleville', 'Coppell', 'Twin Falls', 'New Rochelle',
#        'Broomfield', 'Winnipeg', 'Rockville', 'Manchester', 'Logan',
#        'Sterling Heights', 'Sparks', 'Athens', 'Pocatello', 'Midland',
#        'Holland', 'Saginaw', 'Waukesha', 'Niagara Falls', 'Atlantic City',
#        'Olympia', 'Mobile', 'Garland', 'Reno', 'Kissimmee', 'Aberdeen',
#        'Mission Viejo', 'Canton', 'Bridgeton', 'San Angelo', 'Draper',
#        'Missoula', "St. John's", 'Davis', 'Madison', 'Port Orange',
#        'Muskogee', 'Park Ridge', 'Ontario', 'Saint Cloud', 'Deer Park',
#        'Tigard', 'Manteca', 'Highland Park', 'Pleasant Grove', 'Norman',
#        'Layton', 'Overland Park', 'Springdale', 'Visalia', 'Clarksville',
#        'Kirkwood', 'Hackensack', 'Tinley Park', 'Bangor', 'Thornton',
#        'Champaign', 'Medina', 'Whittier', 'Elkhart', 'Suffolk',
#        'La Quinta', 'Texarkana', 'Gladstone', 'Sheboygan', 'Cheyenne',
#        'Citrus Heights', 'League City', 'Pasco', 'San Marcos',
#        'Coachella', 'Saint Louis', 'Marysville', 'Corpus Christi',
#        'Laurel', 'Mentor', 'Santa Fe', 'Lindenhurst', 'Sanford',
#        'Moncton', 'Dearborn', 'Missouri City', 'Boca Raton', 'Wausau',
#        'Conway', 'Coon Rapids', 'Parker', 'Grapevine', 'Santa Maria',
#        'Royal Oak', 'York', 'Halifax', 'Edinburg', 'Oak Park', 'Danville',
#        'Edmond', 'Wilson', 'Waterloo', 'Yucaipa', 'Orland Park',
#        'Marlborough', 'Bayonne', 'Holyoke', 'Glenview', 'Andover',
#        'Lewiston', 'Pompano Beach', 'Pensacola', 'Murrieta',
#        'Commerce City', 'Billings', 'Gastonia', 'Mishawaka', 'Temecula',
#        'Saint Peters', 'Independence', 'Daytona Beach', 'Morgan Hill',
#        'East Point', 'Manhattan', 'Carol Stream', 'South Bend',
#        'Summerville', 'Burbank', 'La Mesa', 'Margate', 'Rochester Hills',
#        'Arlington Heights', 'Bedford', 'Clifton', 'Goldsboro',
#        'New Castle', 'Baytown', 'Caldwell', 'New Brunswick', 'Regina',
#        'Greeley', 'Redwood City', 'San Luis Obispo', 'Nashua', 'Oswego',
#        'Norfolk', 'Pico Rivera', 'Hagerstown', 'Jupiter', 'Vacaville',
#        'Grand Island', 'Eugene', 'Cedar Rapids', 'Ormond Beach',
#        'West Allis', 'Clovis', 'San Mateo', 'Portage'], dtype=object)

# %%
df["Gross Profit"].unique()
# Out:
# array([  4.9 ,   5.  ,   4.8 ,   6.33,   4.22,   2.5 ,   7.47,  16.8 ,
#          4.98,  10.55,  14.94,  12.25,   2.49,   7.35,  19.92,   7.2 ,
#         10.  ,   7.5 ,  12.  ,   9.6 ,   9.96,  12.66,   9.8 ,   2.45,
#          1.95,  24.5 ,   2.4 ,  12.5 ,  21.1 ,  31.2 ,   8.44,  14.7 ,
#          1.4 ,  12.45,  29.54,  19.2 ,  27.5 ,  21.6 ,   2.11,  15.  ,
#         17.5 ,  17.15,  34.3 ,  29.4 ,  22.5 ,  23.21,  14.77,   6.5 ,
#          4.55,  20.  ,  30.  ,  22.05,  16.88,  17.43,  18.99,  25.  ,
#          2.  ,  14.4 ,  22.41,  24.  ,   1.25,  19.6 ,   1.  ,  24.9 ,
#          0.65,   1.3 ,   3.25,  26.4 ,   0.5 ,   2.8 ,  34.86,   7.15,
#         50.  ,   0.25,   3.9 ,   2.6 ,  31.85,   1.75,  40.  ,  70.  ,
#         35.  ,  60.  ,  80.  ,   9.  ,   5.2 ,   0.75,  32.5 ,   1.5 ,
#         25.32,   5.85,   2.25,  27.43,  27.39,   2.48,   2.1 ,   1.24,
#         90.  ,  29.88,  11.25,  26.95,  33.6 ,  28.8 , 130.  ,   0.6 ,
#         48.  , 100.  ,  32.37,   0.7 ,   6.75,   4.96,   4.2 ,   1.8 ,
#          4.5 ,  32.  ,   7.8 ,   6.2 , 110.  ,   7.44,   7.  ,   3.5 ,
#          3.72])

# %%
df["Ship Mode"].unique()
# Out:
# array(['Standard Class', 'First Class', 'Second Class', 'Same Day'],
#       dtype=object)

# %%
df["Country/Region"].unique()
# Out:
# array(['United States', 'Canada'], dtype=object)

# %%
df["Division"].unique()
# Out:
# array(['Chocolate', 'Other', 'Sugar'], dtype=object)

# %%
df["Product Name"].unique()
# Out:
# array(['Wonka Bar - Triple Dazzle Caramel',
#        'Wonka Bar -Scrumdiddlyumptious', 'Wonka Bar - Fudge Mallows',
#        'Wonka Bar - Milk Chocolate', 'Wonka Bar - Nutty Crunch Surprise',
#        'Wonka Gum', 'SweeTARTS', 'Lickable Wallpaper', 'Kazookles',
#        'Everlasting Gobstopper', 'Fizzy Lifting Drinks', 'Nerds',
#        'Fun Dip', 'Laffy Taffy', 'Hair Toffee'], dtype=object)

# %%
df["Factory"].unique()
# Out:
# array(["Wicked Choccy's", "Lot's O' Nuts", 'Secret Factory',
#        'Sugar Shack', 'The Other Factory'], dtype=object)
